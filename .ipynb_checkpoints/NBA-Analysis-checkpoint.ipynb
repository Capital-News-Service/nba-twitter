# %% [markdown]
# Jake Gluck - Capital News Service - jagluck.github.io
#
# NBA Twitter Analysis

# %%
#import libraries
import pandas as pd
import numpy as np
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from io import StringIO
xrange = range
from tokenize import generate_tokens

# %%
#load twitter conv data gathered by the scraper
df = pd.read_csv('/Users/jagluck/Documents/GitHub/nba-twitter/nba-conv-good.csv')

NBACAPS = {'CAVS','OKCTHUNDER','CELTICS','NYKNICKS','BROOKLYNNETS','PELICANSNBA', 'PACERS', 'ORLANDOMAGIC','TIMBERWOLVES','MIAMIHEAT',
'HORNETS', 'DETROITPISTONS', 'DALLASMAVS', 'LACLIPPERS', 'LAKERS', 'UTAHJAZZ', 'NUGGETS', 'WASHWIZARDS', 'CHICAGOBULLS',
'SPURS', 'SUNS', 'HOUSTONROCKETS', 'WARRIORS', 'ATLHAWKS', 'MEMGRIZZ', 'BUCKS', 'RAPTORS', 'SACRAMENTOKINGS', 'SIXERS', 'TRAILBLAZERS'}

def parts(a):
    """Split a python-tokenizable expression on comma operators"""
    compos = [-1] # compos stores the positions of the relevant commas in the argument string
    compos.extend(t[2][1] for t in generate_tokens(StringIO(a).readline) if t[1] == ',')
    compos.append(len(a))
    return [ a[compos[i]+1:compos[i+1]] for i in xrange(len(compos)-1)]

#coverts to list of strings
def convertType(toConv, makeUpper):
    
    tcs = []
    for tc in toConv:
        chain = parts(tc)
        
        chain2 = []
        for c in chain:
            c = c.strip('[')
            c = c.strip(']')
            c = c.strip(' \'')
            c = c.strip('\'')
            c = c.strip('@')
            chain2.append(c) 
        
        #make uppercase if specified
        chain3 = []
        if makeUpper:
            for c in chain2:
                chain3.append(c.upper())
            tcs.append(chain3)
        else:
            tcs.append(chain2)
        
    return np.array(tcs)


# Helper: counts time value is in list of lists
def countContains(toCount, data):
    count = 0
    for x in data:
        if toCount in x:
            count = count + 1
    return count

# Helper: stores value when value in list of list is found
def countLengths(toCount, data1, data2):
    count = []
    for x, y in zip(data1, data2):
        if toCount in x:
            count.append(y)
    return np.mean(count)
    
# convert types  
df = df.drop(['Unnamed: 0'], axis=1)
df = df.drop(['to'], axis=1)
df = df.drop(['from'], axis=1)
df['names'] = convertType(df['names'], False)
df['usernames'] = convertType(df['usernames'], True)
df['dates'] = convertType(df['dates'], True)
df['tweets'] = convertType(df['tweets'], True)

lens = []
for ob in df["names"]:
    lens.append(len(ob))
df["num_parties"] = lens


two_parties = df.loc[df["num_parties"] == 2]
sort = df.sort_values(by='num_parties', ascending=False)
# Out:
#   File "<ipython-input-99-5715ebbe85ca>", line 28
#     c = c.strip('@)
#                    ^
# SyntaxError: EOL while scanning string literal

# %%
## What is the typical converation size? ##########
df['size'].describe()
# Out:
# count    1917.000000
# mean        2.838289
# std         2.161278
# min         2.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max        52.000000
# Name: size, dtype: float64

# %%
### What teams Tweet the most #######
names = []
participations = []
lengths = []
for name in NBACAPS:
    names.append(name)
    participations.append(countContains(name,df['usernames']))
    lengths.append(countLengths(name,df['usernames'],df['size']))

teams = pd.DataFrame(
        {'name': names,
         'participation': participations,
         'avg_lengths': lengths
        })
    
teams = teams.sort_values(by='participation', ascending=False)
print(teams)
print("Participation " + str(np.mean(teams['participation'])))

#What teams have the longest and shortest conversations
teams = teams.sort_values(by='avg_lengths', ascending=False)
print(teams)

#What teams talk to other teams the most/least? 

def countDuoConvos(name, name2):
    count = 0
    for x in df['usernames']:
        if name in x:
            if name2 in x:
                count = count + 1
    return count
 
tos = []
froms = []
convo_counts = []

for name in NBACAPS:
    for name2 in NBACAPS:
        if name != name2:
            if name < name2:
                tos.append(name)
                froms.append(name2)
                convo_counts.append(countDuoConvos(name, name2))
                
convos = pd.DataFrame(
        {'team_1': tos,
         'team_2': froms,
         'convo_count': convo_counts
        })
 
convos = convos.sort_values(by='convo_count', ascending=False)       
print(convos)
print(np.mean(convos['convo_count']))
# Out:
#     avg_lengths             name  participation
# 0           NaN      WASHWIZARDS              0
# 1           NaN        MIAMIHEAT              0
# 28          NaN           SIXERS              0
# 27          NaN          NUGGETS              0
# 26          NaN          CELTICS              0
# 25          NaN  SACRAMENTOKINGS              0
# 24          NaN       OKCTHUNDER              0
# 23          NaN         MEMGRIZZ              0
# 22          NaN       DALLASMAVS              0
# 21          NaN         WARRIORS              0
# 20          NaN   HOUSTONROCKETS              0
# 19          NaN             CAVS              0
# 18          NaN         NYKNICKS              0
# 17          NaN            BUCKS              0
# 16          NaN           PACERS              0
# 15          NaN             SUNS              0
# 14          NaN   DETROITPISTONS              0
# 13          NaN          HORNETS              0
# 12          NaN       LACLIPPERS              0
# 11          NaN         ATLHAWKS              0
# 10          NaN         UTAHJAZZ              0
# 9           NaN     TRAILBLAZERS              0
# 8           NaN          RAPTORS              0
# 7           NaN           LAKERS              0
# 6           NaN      PELICANSNBA              0
# 5           NaN            SPURS              0
# 4           NaN     ORLANDOMAGIC              0
# 3           NaN     TIMBERWOLVES              0
# 2           NaN     BROOKLYNNETS              0
# 29          NaN     CHICAGOBULLS              0
# Participation 0.0
#     avg_lengths             name  participation
# 0           NaN      WASHWIZARDS              0
# 1           NaN        MIAMIHEAT              0
# 28          NaN           SIXERS              0
# 27          NaN          NUGGETS              0
# 26          NaN          CELTICS              0
# 25          NaN  SACRAMENTOKINGS              0
# 24          NaN       OKCTHUNDER              0
# 23          NaN         MEMGRIZZ              0
# 22          NaN       DALLASMAVS              0
# 21          NaN         WARRIORS              0
# 20          NaN   HOUSTONROCKETS              0
# 19          NaN             CAVS              0
# 18          NaN         NYKNICKS              0
# 17          NaN            BUCKS              0
# 16          NaN           PACERS              0
# 15          NaN             SUNS              0
# 14          NaN   DETROITPISTONS              0
# 13          NaN          HORNETS              0
# 12          NaN       LACLIPPERS              0
# 11          NaN         ATLHAWKS              0
# 10          NaN         UTAHJAZZ              0
# 9           NaN     TRAILBLAZERS              0
# 8           NaN          RAPTORS              0
# 7           NaN           LAKERS              0
# 6           NaN      PELICANSNBA              0
# 5           NaN            SPURS              0
# 4           NaN     ORLANDOMAGIC              0
# 3           NaN     TIMBERWOLVES              0
# 2           NaN     BROOKLYNNETS              0
# 29          NaN     CHICAGOBULLS              0
#      convo_count          team_1           team_2
# 0              0       MIAMIHEAT      WASHWIZARDS
# 286            0  HOUSTONROCKETS            SPURS
# 297            0  HOUSTONROCKETS         MEMGRIZZ
# 296            0  HOUSTONROCKETS         WARRIORS
# 295            0  HOUSTONROCKETS         NYKNICKS
# 294            0  HOUSTONROCKETS           PACERS
# 293            0  HOUSTONROCKETS             SUNS
# 292            0  HOUSTONROCKETS       LACLIPPERS
# 291            0  HOUSTONROCKETS         UTAHJAZZ
# 290            0  HOUSTONROCKETS     TRAILBLAZERS
# 289            0  HOUSTONROCKETS          RAPTORS
# 288            0  HOUSTONROCKETS           LAKERS
# 287            0  HOUSTONROCKETS      PELICANSNBA
# 285            0  HOUSTONROCKETS     ORLANDOMAGIC
# 326            0        MEMGRIZZ      WASHWIZARDS
# 284            0  HOUSTONROCKETS     TIMBERWOLVES
# 283            0  HOUSTONROCKETS        MIAMIHEAT
# 282            0  HOUSTONROCKETS      WASHWIZARDS
# 281            0            CAVS     CHICAGOBULLS
# 280            0            CAVS           SIXERS
# 279            0            CAVS          NUGGETS
# 278            0            CAVS          CELTICS
# 277            0            CAVS  SACRAMENTOKINGS
# 276            0            CAVS       OKCTHUNDER
# 275            0            CAVS         MEMGRIZZ
# 274            0            CAVS       DALLASMAVS
# 298            0  HOUSTONROCKETS       OKCTHUNDER
# 299            0  HOUSTONROCKETS  SACRAMENTOKINGS
# 300            0  HOUSTONROCKETS          NUGGETS
# 301            0  HOUSTONROCKETS           SIXERS
# ..           ...             ...              ...
# 112            0        ATLHAWKS     ORLANDOMAGIC
# 111            0        ATLHAWKS     TIMBERWOLVES
# 134            0        ATLHAWKS          NUGGETS
# 136            0        ATLHAWKS     CHICAGOBULLS
# 161            0         HORNETS      PELICANSNBA
# 137            0      LACLIPPERS      WASHWIZARDS
# 160            0         HORNETS            SPURS
# 159            0         HORNETS     ORLANDOMAGIC
# 158            0         HORNETS     TIMBERWOLVES
# 157            0         HORNETS        MIAMIHEAT
# 156            0         HORNETS      WASHWIZARDS
# 155            0      LACLIPPERS           SIXERS
# 154            0      LACLIPPERS          NUGGETS
# 153            0      LACLIPPERS  SACRAMENTOKINGS
# 152            0      LACLIPPERS       OKCTHUNDER
# 151            0      LACLIPPERS         MEMGRIZZ
# 150            0      LACLIPPERS         WARRIORS
# 149            0      LACLIPPERS         NYKNICKS
# 148            0      LACLIPPERS           PACERS
# 147            0      LACLIPPERS             SUNS
# 146            0      LACLIPPERS         UTAHJAZZ
# 145            0      LACLIPPERS     TRAILBLAZERS
# 144            0      LACLIPPERS          RAPTORS
# 143            0      LACLIPPERS           LAKERS
# 142            0      LACLIPPERS      PELICANSNBA
# 141            0      LACLIPPERS            SPURS
# 140            0      LACLIPPERS     ORLANDOMAGIC
# 139            0      LACLIPPERS     TIMBERWOLVES
# 138            0      LACLIPPERS        MIAMIHEAT
# 434            0    CHICAGOBULLS           SIXERS
#
# [435 rows x 3 columns]
# 0.0
# /Users/jagluck/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/jagluck/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# What percent of each team is sent to other teams

team_name = []
to_name = []
percent = []
for t_index, t_row in teams.iterrows():
    total = t_row['participation']
    name = t_row['name']
    for c_index, c_row in convos.iterrows():
        if (name == c_row['team_1']):
            team_name.append(name)
            to_name.append(c_row['team_2'])
            count = c_row['convo_count']
            if (count == 0):
                percent.append(0)
            else:
                percent.append(c_row['convo_count']/total)
            
convo_percent = pd.DataFrame(
        {'from': team_name,
         'to': to_name,
         'percent': percent
        })
        
convo_percent = convo_percent.sort_values(by='percent', ascending=False)  
hawks = convo_percent.loc[convo_percent["from"] == "ATLHAWKS"]
print(convo_percent)
# Out:
#                from  percent               to
# 0         MIAMIHEAT        0      WASHWIZARDS
# 286      LACLIPPERS        0            SPURS
# 297        ATLHAWKS        0         MEMGRIZZ
# 296        ATLHAWKS        0       OKCTHUNDER
# 295        ATLHAWKS        0  SACRAMENTOKINGS
# 294        ATLHAWKS        0          CELTICS
# 293        ATLHAWKS        0           SIXERS
# 292        ATLHAWKS        0     BROOKLYNNETS
# 291        ATLHAWKS        0        MIAMIHEAT
# 290        ATLHAWKS        0      WASHWIZARDS
# 289      LACLIPPERS        0        MIAMIHEAT
# 288      LACLIPPERS        0     TIMBERWOLVES
# 287      LACLIPPERS        0     ORLANDOMAGIC
# 285      LACLIPPERS        0      PELICANSNBA
# 326         RAPTORS        0         WARRIORS
# 284      LACLIPPERS        0           LAKERS
# 283      LACLIPPERS        0          RAPTORS
# 282      LACLIPPERS        0     TRAILBLAZERS
# 281      LACLIPPERS        0         UTAHJAZZ
# 280      LACLIPPERS        0             SUNS
# 279      LACLIPPERS        0           PACERS
# 278      LACLIPPERS        0         NYKNICKS
# 277      LACLIPPERS        0         WARRIORS
# 276      LACLIPPERS        0         MEMGRIZZ
# 275      LACLIPPERS        0       OKCTHUNDER
# 274      LACLIPPERS        0  SACRAMENTOKINGS
# 298        ATLHAWKS        0       DALLASMAVS
# 299        ATLHAWKS        0         WARRIORS
# 300        ATLHAWKS        0   HOUSTONROCKETS
# 301        ATLHAWKS        0             CAVS
# ..              ...      ...              ...
# 112      DALLASMAVS        0       LACLIPPERS
# 111      DALLASMAVS        0          HORNETS
# 134  HOUSTONROCKETS        0          RAPTORS
# 136  HOUSTONROCKETS        0      PELICANSNBA
# 161            CAVS        0         UTAHJAZZ
# 137  HOUSTONROCKETS        0     ORLANDOMAGIC
# 160            CAVS        0       LACLIPPERS
# 159            CAVS        0          HORNETS
# 158            CAVS        0   DETROITPISTONS
# 157            CAVS        0             SUNS
# 156            CAVS        0           PACERS
# 155            CAVS        0         NYKNICKS
# 154            CAVS        0   HOUSTONROCKETS
# 153            CAVS        0         WARRIORS
# 152            CAVS        0       DALLASMAVS
# 151            CAVS        0         MEMGRIZZ
# 150            CAVS        0       OKCTHUNDER
# 149            CAVS        0  SACRAMENTOKINGS
# 148            CAVS        0          CELTICS
# 147            CAVS        0          NUGGETS
# 146            CAVS        0           SIXERS
# 145            CAVS        0     CHICAGOBULLS
# 144  HOUSTONROCKETS        0           SIXERS
# 143  HOUSTONROCKETS        0          NUGGETS
# 142  HOUSTONROCKETS        0  SACRAMENTOKINGS
# 141  HOUSTONROCKETS        0       OKCTHUNDER
# 140  HOUSTONROCKETS        0      WASHWIZARDS
# 139  HOUSTONROCKETS        0        MIAMIHEAT
# 138  HOUSTONROCKETS        0     TIMBERWOLVES
# 434    CHICAGOBULLS        0           SIXERS
#
# [435 rows x 3 columns]

# %%
# How has the number of conversations changed over time?

years = []
for index, row in df.iterrows():
    year = row['dates'][0][-4:]
    years.append(year)

output = set()
for x in years:
    output.add(x)
output = sorted(list(output))
f_years = []
counts = []

for x in output:
    f_years.append(x)
    counts.append(years.count(x))
    
year_count = pd.DataFrame(
        {'year': f_years,
         'count': counts
        }) 
        
print(year_count)
# Out:
#    count  year
# 0      8  012'
# 1     41  013'
# 2    310  014'
# 3    518  015'
# 4    427  016'
# 5    613  017'

# %%
# What was the language of the tweets like/ \sentiment analysis

tweets = df['tweets']
names = df['usernames']
text = []
team = []

for tweet, name in zip(tweets,names):

    for c in tweet:
        text.append(c)
        
    for n in name:
        team.append(n)

neg = []
pos = []
neu = []
comp = []

analyzer = SentimentIntensityAnalyzer()

for t in text:
   vs = analyzer.polarity_scores(t)
   neg.append(vs['neg'])
   pos.append(vs['pos'])
   neu.append(vs['neu'])
   comp.append(vs['compound'])

all_tweets = pd.DataFrame(
        {'text': text,
         'team': team,
         'neg' : neg,
         'pos' : pos,
         'neu' : neu,
         'comp' : comp
        }) 

all_tweets=all_tweets[all_tweets['team'].isin(NBACAPS)]

print("Pos Avg: " + str(all_tweets['pos'].mean()))
print("Pos Max: " + str(all_tweets['pos'].max()))

print("Neg Avg: " + str(all_tweets['neg'].mean()))
print("Neg Max: " + str(all_tweets['neg'].max()))

print("Neu Avg: " + str(all_tweets['neu'].mean()))

print("Comp Avg: " + str(all_tweets['comp'].mean()))

negative = all_tweets[all_tweets['neg'] == 1]

print("\nMost Negative Tweets")
print(negative)

positive = all_tweets[all_tweets['pos'] == 1]
print("\nMost Positive Tweets")
print(positive)

pos_groups = all_tweets.groupby('team')['pos'].mean()
pos_groups = pos_groups.sort_values(ascending=False)
print("\nTeam Pos Avg")
print(pos_groups)

neg_groups = all_tweets.groupby('team')['neg'].mean()
neg_groups = neg_groups.sort_values(ascending=False)
print("\nTeam Neg Avg")
print(neg_groups)

comp_groups = all_tweets.groupby('team')['comp'].mean()
comp_groups = comp_groups.sort_values(ascending=False)
print("\nTeam Comp Avg")
print(comp_groups)
# Out:
# Pos Avg: nan
# Pos Max: nan
# Neg Avg: nan
# Neg Max: nan
# Neu Avg: nan
# Comp Avg: nan
#
# Most Negative Tweets
# Empty DataFrame
# Columns: [comp, neg, neu, pos, team, text]
# Index: []
#
# Most Positive Tweets
# Empty DataFrame
# Columns: [comp, neg, neu, pos, team, text]
# Index: []
#
# Team Pos Avg
# Series([], Name: pos, dtype: float64)
#
# Team Neg Avg
# Series([], Name: neg, dtype: float64)
#
# Team Comp Avg
# Series([], Name: comp, dtype: float64)
