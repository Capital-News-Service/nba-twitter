# %% [markdown]
# Jake Gluck - Capital News Service - jagluck.github.io
#
# NBA Twitter Analysis

# %%
#import libraries
import pandas as pd
import numpy as np
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from io import StringIO
xrange = range
from tokenize import generate_tokens

# %%
#load twitter conv data gathered by the scraper
df = pd.read_csv('/Users/jagluck/Documents/GitHub/nba-twitter/nba-conv-thurs.csv')

NBACAPS = ['CAVS','OKCTHUNDER','CELTICS','NYKNICKS','BROOKLYNNETS','PELICANSNBA', 'PACERS', 'ORLANDOMAGIC','TIMBERWOLVES','MIAMIHEAT',
'HORNETS', 'DETROITPISTONS', 'DALLASMAVS', 'LACLIPPERS', 'LAKERS', 'UTAHJAZZ', 'NUGGETS', 'WASHWIZARDS', 'CHICAGOBULLS',
'SPURS', 'SUNS', 'HOUSTONROCKETS', 'WARRIORS', 'ATLHAWKS', 'MEMGRIZZ', 'BUCKS', 'RAPTORS', 'SACRAMENTOKINGS', 'SIXERS', 'TRAILBLAZERS']

def parts(a):
    """Split a python-tokenizable expression on comma operators"""
    compos = [-1] # compos stores the positions of the relevant commas in the argument string
    compos.extend(t[2][1] for t in generate_tokens(StringIO(a).readline) if t[1] == ',')
    compos.append(len(a))
    return [ a[compos[i]+1:compos[i+1]] for i in xrange(len(compos)-1)]

#coverts to list of strings
def convertType(toConv, makeUpper):
    
    tcs = []
    for tc in toConv:
        chain = parts(tc)
        
        chain2 = []
        for c in chain:
            c = c.strip('[')
            c = c.strip(']')
            c = c.strip(' \'')
            c = c.strip('\'')
            c = c.strip('@')
            chain2.append(c) 
        
        #make uppercase if specified
        chain3 = []
        if makeUpper:
            for c in chain2:
                chain3.append(c.upper())
            tcs.append(chain3)
        else:
            tcs.append(chain2)
        
    return np.array(tcs)


# Helper: counts time value is in list of lists
def countContains(toCount, data):
    count = 0
    for x in data:
        if toCount in x:
            count = count + 1
    return count

# Helper: stores value when value in list of list is found
def countLengths(toCount, data1, data2):
    count = []
    for x, y in zip(data1, data2):
        if toCount in x:
            count.append(y)
    return np.mean(count)
    
# convert types  
df = df.drop(['Unnamed: 0'], axis=1)
df = df.drop(['to'], axis=1)
df = df.drop(['from'], axis=1)
df['names'] = convertType(df['names'], False)
df['usernames'] = convertType(df['usernames'], True)
df['dates'] = convertType(df['dates'], True)
df['tweets'] = convertType(df['tweets'], True)

lens = []
for ob in df["names"]:
    lens.append(len(ob))
df["num_parties"] = lens


two_parties = df.loc[df["num_parties"] == 2]
sort = df.sort_values(by='num_parties', ascending=False)

# %%
## What is the typical converation size? ##########
df['size'].describe()
# Out:
# count    1918.000000
# mean        2.839416
# std         2.154025
# min         2.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max        52.000000
# Name: size, dtype: float64

# %%
### What teams Tweet the most #######
names = []
participations = []
lengths = []
for name in NBACAPS:
    names.append(name)
    participations.append(countContains(name,df['usernames']))
    lengths.append(countLengths(name,df['usernames'],df['size']))

teams = pd.DataFrame(
        {'name': names,
         'participation': participations,
         'avg_lengths': lengths
        })
    
teams = teams.sort_values(by='participation', ascending=False)
#print(teams)
#print("Participation " + str(np.mean(teams['participation'])))

#What teams have the longest and shortest conversations
teams = teams.sort_values(by='avg_lengths', ascending=False)
#print(teams)

#What teams talk to other teams the most/least? 

def countDuoConvos(name, name2):
    count = 0
    for x in df['usernames']:
        if name in x:
            if name2 in x:
                count = count + 1
    return count
 
tos = []
froms = []
convo_counts = []

for name in NBACAPS:
    for name2 in NBACAPS:
        if name != name2:
            if name < name2:
                tos.append(NBACAPS.index(name))
                froms.append(NBACAPS.index(name2))
                convo_counts.append(countDuoConvos(name, name2))
                
convos = pd.DataFrame(
        {'team_1': tos,
         'team_2': froms,
         'convo_count': convo_counts
        })
 
convos = convos.sort_values(by='convo_count', ascending=False)       
print(np.mean(convos['convo_count']))
with pd.option_context('display.max_rows', None, 'display.max_columns', 3):
    print(convos)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-4a552bcb20ea> in <module>()
#      40         if name != name2:
#      41             if name < name2:
# ---> 42                 tos.append(NBACAPS.index(name))
#      43                 froms.append(NBACAPS.index(name2))
#      44                 convo_counts.append(countDuoConvos(name, name2))
#
# AttributeError: 'set' object has no attribute 'index'

# %%
# What percent of each team is sent to other teams

team_name = []
to_name = []
percent = []
for t_index, t_row in teams.iterrows():
    total = t_row['participation']
    name = t_row['name']
    for c_index, c_row in convos.iterrows():
        if (name == c_row['team_1']):
            team_name.append(name)
            to_name.append(c_row['team_2'])
            count = c_row['convo_count']
            if (count == 0):
                percent.append(0)
            else:
                percent.append(c_row['convo_count']/total)
            
convo_percent = pd.DataFrame(
        {'from': team_name,
         'to': to_name,
         'percent': percent
        })
        
convo_percent = convo_percent.sort_values(by='percent', ascending=False)  
hawks = convo_percent.loc[convo_percent["from"] == "ATLHAWKS"]
with pd.option_context('display.max_rows', None, 'display.max_columns', 3):
    print(convo_percent)
# Out:
#                 from               to   percent
# 49        OKCTHUNDER     TRAILBLAZERS  0.411765
# 158         NYKNICKS     TIMBERWOLVES  0.263158
# 362     BROOKLYNNETS     TRAILBLAZERS  0.255814
# 417           LAKERS     TRAILBLAZERS  0.250000
# 111          CELTICS     TRAILBLAZERS  0.243243
# 278     CHICAGOBULLS             SUNS  0.219512
# 308   HOUSTONROCKETS     TRAILBLAZERS  0.215385
# 202       LACLIPPERS     TRAILBLAZERS  0.201087
# 279     CHICAGOBULLS  SACRAMENTOKINGS  0.195122
# 280     CHICAGOBULLS     TRAILBLAZERS  0.195122
# 77            SIXERS             SUNS  0.186528
# 352      PELICANSNBA     TRAILBLAZERS  0.179245
# 84             BUCKS     TRAILBLAZERS  0.174157
# 406           PACERS     TRAILBLAZERS  0.171429
# 309   HOUSTONROCKETS  SACRAMENTOKINGS  0.169231
# 419           LAKERS  SACRAMENTOKINGS  0.166667
# 418           LAKERS     TIMBERWOLVES  0.166667
# 240             CAVS  SACRAMENTOKINGS  0.160000
# 159         NYKNICKS     TRAILBLAZERS  0.157895
# 160         NYKNICKS  SACRAMENTOKINGS  0.157895
# 23           HORNETS           SIXERS  0.152778
# 136   DETROITPISTONS     TRAILBLAZERS  0.150000
# 241             CAVS     TRAILBLAZERS  0.146667
# 62           NUGGETS  SACRAMENTOKINGS  0.145038
# 221         MEMGRIZZ  SACRAMENTOKINGS  0.141304
# 302            SPURS     TRAILBLAZERS  0.140351
# 310   HOUSTONROCKETS     TIMBERWOLVES  0.138462
# 0         DALLASMAVS             SUNS  0.137931
# 112          CELTICS      WASHWIZARDS  0.135135
# 78            SIXERS     TRAILBLAZERS  0.129534
# 340          RAPTORS     TRAILBLAZERS  0.127273
# 222         MEMGRIZZ     TRAILBLAZERS  0.125000
# 24           HORNETS         UTAHJAZZ  0.125000
# 172         ATLHAWKS             SUNS  0.120773
# 242             CAVS         UTAHJAZZ  0.120000
# 203       LACLIPPERS  SACRAMENTOKINGS  0.119565
# 223         MEMGRIZZ          NUGGETS  0.119565
# 50        OKCTHUNDER  SACRAMENTOKINGS  0.117647
# 1         DALLASMAVS     TIMBERWOLVES  0.114943
# 407           PACERS  SACRAMENTOKINGS  0.114286
# 173         ATLHAWKS     TIMBERWOLVES  0.113527
# 266     ORLANDOMAGIC     TIMBERWOLVES  0.112782
# 137   DETROITPISTONS           SIXERS  0.112500
# 44              SUNS     TRAILBLAZERS  0.111588
# 113          CELTICS         UTAHJAZZ  0.108108
# 114          CELTICS       LACLIPPERS  0.108108
# 63           NUGGETS           SIXERS  0.106870
# 267     ORLANDOMAGIC             SUNS  0.105263
# 161         NYKNICKS         UTAHJAZZ  0.105263
# 303            SPURS     TIMBERWOLVES  0.105263
# 392        MIAMIHEAT     ORLANDOMAGIC  0.103448
# 393        MIAMIHEAT             SUNS  0.103448
# 3         DALLASMAVS           SIXERS  0.103448
# 391        MIAMIHEAT  SACRAMENTOKINGS  0.103448
# 390        MIAMIHEAT          RAPTORS  0.103448
# 394        MIAMIHEAT     TRAILBLAZERS  0.103448
# 2         DALLASMAVS     TRAILBLAZERS  0.103448
# 204       LACLIPPERS     TIMBERWOLVES  0.103261
# 138   DETROITPISTONS     TIMBERWOLVES  0.100000
# 341          RAPTORS         WARRIORS  0.100000
# 64           NUGGETS             SUNS  0.099237
# 281     CHICAGOBULLS         MEMGRIZZ  0.097561
# 85             BUCKS           SIXERS  0.095506
# 86             BUCKS     TIMBERWOLVES  0.095506
# 45              SUNS     TIMBERWOLVES  0.094421
# 243             CAVS         WARRIORS  0.093333
# 311   HOUSTONROCKETS      WASHWIZARDS  0.092308
# 312   HOUSTONROCKETS         MEMGRIZZ  0.092308
# 4         DALLASMAVS          NUGGETS  0.091954
# 139   DETROITPISTONS             SUNS  0.087500
# 353      PELICANSNBA  SACRAMENTOKINGS  0.084906
# 87             BUCKS             SUNS  0.084270
# 25           HORNETS         MEMGRIZZ  0.083333
# 420           LAKERS      WASHWIZARDS  0.083333
# 26           HORNETS  SACRAMENTOKINGS  0.083333
# 27           HORNETS             SUNS  0.083333
# 421           LAKERS           PACERS  0.083333
# 268     ORLANDOMAGIC     TRAILBLAZERS  0.082707
# 349     TRAILBLAZERS         WARRIORS  0.082192
# 363     BROOKLYNNETS     TIMBERWOLVES  0.081395
# 116          CELTICS         MEMGRIZZ  0.081081
# 115          CELTICS     TIMBERWOLVES  0.081081
# 5         DALLASMAVS  SACRAMENTOKINGS  0.080460
# 244             CAVS     TIMBERWOLVES  0.080000
# 174         ATLHAWKS     TRAILBLAZERS  0.079710
# 88             BUCKS       LACLIPPERS  0.078652
# 175         ATLHAWKS            BUCKS  0.077295
# 46              SUNS         WARRIORS  0.077253
# 328     TIMBERWOLVES         UTAHJAZZ  0.077253
# 65           NUGGETS     TIMBERWOLVES  0.076336
# 332  SACRAMENTOKINGS     TRAILBLAZERS  0.075658
# 269     ORLANDOMAGIC           SIXERS  0.075188
# 140   DETROITPISTONS  SACRAMENTOKINGS  0.075000
# 282     CHICAGOBULLS          NUGGETS  0.073171
# 284     CHICAGOBULLS         UTAHJAZZ  0.073171
# 283     CHICAGOBULLS     ORLANDOMAGIC  0.073171
# 342          RAPTORS  SACRAMENTOKINGS  0.072727
# 79            SIXERS         WARRIORS  0.072539
# 333  SACRAMENTOKINGS             SUNS  0.072368
# 224         MEMGRIZZ         UTAHJAZZ  0.070652
# 176         ATLHAWKS           SIXERS  0.070048
# 364     BROOKLYNNETS  SACRAMENTOKINGS  0.069767
# 365     BROOKLYNNETS         MEMGRIZZ  0.069767
# 29           HORNETS      WASHWIZARDS  0.069444
# 28           HORNETS     TIMBERWOLVES  0.069444
# 7         DALLASMAVS         UTAHJAZZ  0.068966
# 6         DALLASMAVS          RAPTORS  0.068966
# 395        MIAMIHEAT      PELICANSNBA  0.068966
# 329     TIMBERWOLVES     TRAILBLAZERS  0.068670
# 271     ORLANDOMAGIC  SACRAMENTOKINGS  0.067669
# 270     ORLANDOMAGIC         WARRIORS  0.067669
# 89             BUCKS         UTAHJAZZ  0.067416
# 205       LACLIPPERS             SUNS  0.065217
# 177         ATLHAWKS  SACRAMENTOKINGS  0.062802
# 178         ATLHAWKS     ORLANDOMAGIC  0.062802
# 334  SACRAMENTOKINGS           SIXERS  0.062500
# 141   DETROITPISTONS          HORNETS  0.062500
# 90             BUCKS   DETROITPISTONS  0.061798
# 313   HOUSTONROCKETS         WARRIORS  0.061538
# 66           NUGGETS     TRAILBLAZERS  0.061069
# 67           NUGGETS         UTAHJAZZ  0.061069
# 207       LACLIPPERS         MEMGRIZZ  0.059783
# 206       LACLIPPERS          NUGGETS  0.059783
# 51        OKCTHUNDER         UTAHJAZZ  0.058824
# 366     BROOKLYNNETS      WASHWIZARDS  0.058140
# 180         ATLHAWKS      WASHWIZARDS  0.057971
# 179         ATLHAWKS         WARRIORS  0.057971
# 9         DALLASMAVS       LACLIPPERS  0.057471
# 8         DALLASMAVS         WARRIORS  0.057471
# 409           PACERS      WASHWIZARDS  0.057143
# 408           PACERS         UTAHJAZZ  0.057143
# 411           PACERS     TIMBERWOLVES  0.057143
# 410           PACERS         WARRIORS  0.057143
# 350     TRAILBLAZERS         UTAHJAZZ  0.057078
# 80            SIXERS     TIMBERWOLVES  0.056995
# 354      PELICANSNBA           SIXERS  0.056604
# 91             BUCKS       DALLASMAVS  0.056180
# 335  SACRAMENTOKINGS     TIMBERWOLVES  0.055921
# 337  SACRAMENTOKINGS         WARRIORS  0.055921
# 336  SACRAMENTOKINGS         UTAHJAZZ  0.055921
# 47              SUNS         UTAHJAZZ  0.055794
# 182         ATLHAWKS       DALLASMAVS  0.055556
# 181         ATLHAWKS       LACLIPPERS  0.055556
# 31           HORNETS            SPURS  0.055556
# 30           HORNETS       LACLIPPERS  0.055556
# 343          RAPTORS         UTAHJAZZ  0.054545
# 209       LACLIPPERS           SIXERS  0.054348
# 225         MEMGRIZZ            SPURS  0.054348
# 226         MEMGRIZZ     TIMBERWOLVES  0.054348
# 208       LACLIPPERS          RAPTORS  0.054348
# 118          CELTICS   DETROITPISTONS  0.054054
# 119          CELTICS          NUGGETS  0.054054
# 120          CELTICS            SPURS  0.054054
# 121          CELTICS  SACRAMENTOKINGS  0.054054
# 122          CELTICS         WARRIORS  0.054054
# 123          CELTICS           SIXERS  0.054054
# 124          CELTICS       DALLASMAVS  0.054054
# 117          CELTICS     ORLANDOMAGIC  0.054054
# 68           NUGGETS         WARRIORS  0.053435
# 245             CAVS       DALLASMAVS  0.053333
# 246             CAVS          HORNETS  0.053333
# 163         NYKNICKS         WARRIORS  0.052632
# 164         NYKNICKS           SIXERS  0.052632
# 165         NYKNICKS      WASHWIZARDS  0.052632
# 162         NYKNICKS             SUNS  0.052632
# 305            SPURS      WASHWIZARDS  0.052632
# 304            SPURS             SUNS  0.052632
# 272     ORLANDOMAGIC         UTAHJAZZ  0.052632
# 184         ATLHAWKS      PELICANSNBA  0.050725
# 183         ATLHAWKS          NUGGETS  0.050725
# 95             BUCKS         WARRIORS  0.050562
# 94             BUCKS  SACRAMENTOKINGS  0.050562
# 93             BUCKS      WASHWIZARDS  0.050562
# 92             BUCKS          NUGGETS  0.050562
# 142   DETROITPISTONS       LACLIPPERS  0.050000
# 143   DETROITPISTONS          RAPTORS  0.050000
# 229         MEMGRIZZ      WASHWIZARDS  0.048913
# 228         MEMGRIZZ           SIXERS  0.048913
# 227         MEMGRIZZ      PELICANSNBA  0.048913
# 210       LACLIPPERS         UTAHJAZZ  0.048913
# 185         ATLHAWKS         UTAHJAZZ  0.048309
# 356      PELICANSNBA         WARRIORS  0.047170
# 357      PELICANSNBA             SUNS  0.047170
# 355      PELICANSNBA         UTAHJAZZ  0.047170
# 81            SIXERS      WASHWIZARDS  0.046632
# 367     BROOKLYNNETS             SUNS  0.046512
# 368     BROOKLYNNETS       LACLIPPERS  0.046512
# 314   HOUSTONROCKETS             SUNS  0.046154
# 315   HOUSTONROCKETS       LACLIPPERS  0.046154
# 316   HOUSTONROCKETS     ORLANDOMAGIC  0.046154
# 10        DALLASMAVS          HORNETS  0.045977
# 11        DALLASMAVS     ORLANDOMAGIC  0.045977
# 12        DALLASMAVS   HOUSTONROCKETS  0.045977
# 344          RAPTORS             SUNS  0.045455
# 273     ORLANDOMAGIC          RAPTORS  0.045113
# 230         MEMGRIZZ     ORLANDOMAGIC  0.043478
# 34           HORNETS     ORLANDOMAGIC  0.041667
# 33           HORNETS     TRAILBLAZERS  0.041667
# 32           HORNETS          NUGGETS  0.041667
# 238         UTAHJAZZ      WASHWIZARDS  0.040462
# 247             CAVS           SIXERS  0.040000
# 252             CAVS            SPURS  0.040000
# 250             CAVS      PELICANSNBA  0.040000
# 249             CAVS      WASHWIZARDS  0.040000
# 248             CAVS       LACLIPPERS  0.040000
# 251             CAVS         MEMGRIZZ  0.040000
# 96             BUCKS            SPURS  0.039326
# 186         ATLHAWKS   DETROITPISTONS  0.038647
# 330     TIMBERWOLVES      WASHWIZARDS  0.038627
# 69           NUGGETS     ORLANDOMAGIC  0.038168
# 231         MEMGRIZZ         WARRIORS  0.038043
# 358      PELICANSNBA     TIMBERWOLVES  0.037736
# 274     ORLANDOMAGIC      PELICANSNBA  0.037594
# 145   DETROITPISTONS         WARRIORS  0.037500
# 144   DETROITPISTONS            SPURS  0.037500
# 338  SACRAMENTOKINGS            SPURS  0.036184
# 306            SPURS         UTAHJAZZ  0.035088
# 371     BROOKLYNNETS   HOUSTONROCKETS  0.034884
# 369     BROOKLYNNETS     ORLANDOMAGIC  0.034884
# 370     BROOKLYNNETS          RAPTORS  0.034884
# 397        MIAMIHEAT     TIMBERWOLVES  0.034483
# 15        DALLASMAVS   DETROITPISTONS  0.034483
# 14        DALLASMAVS      WASHWIZARDS  0.034483
# 13        DALLASMAVS         MEMGRIZZ  0.034483
# 396        MIAMIHEAT            SPURS  0.034483
# 398        MIAMIHEAT      WASHWIZARDS  0.034483
# 399        MIAMIHEAT           SIXERS  0.034483
# 351     TRAILBLAZERS      WASHWIZARDS  0.034247
# 187         ATLHAWKS          RAPTORS  0.033816
# 188         ATLHAWKS          HORNETS  0.033816
# 189         ATLHAWKS             CAVS  0.033816
# 97             BUCKS     ORLANDOMAGIC  0.033708
# 232         MEMGRIZZ          RAPTORS  0.032609
# 233         MEMGRIZZ             SUNS  0.032609
# 212       LACLIPPERS            SPURS  0.032609
# 211       LACLIPPERS      PELICANSNBA  0.032609
# 317   HOUSTONROCKETS           SIXERS  0.030769
# 318   HOUSTONROCKETS         UTAHJAZZ  0.030769
# 275     ORLANDOMAGIC      WASHWIZARDS  0.030075
# 331     TIMBERWOLVES         WARRIORS  0.030043
# 339  SACRAMENTOKINGS      WASHWIZARDS  0.029605
# 190         ATLHAWKS         MEMGRIZZ  0.028986
# 413           PACERS          RAPTORS  0.028571
# 412           PACERS      PELICANSNBA  0.028571
# 359      PELICANSNBA            SPURS  0.028302
# 98             BUCKS      PELICANSNBA  0.028090
# 99             BUCKS          HORNETS  0.028090
# 100            BUCKS   HOUSTONROCKETS  0.028090
# 345          RAPTORS           SIXERS  0.027273
# 214       LACLIPPERS         WARRIORS  0.027174
# 213       LACLIPPERS      WASHWIZARDS  0.027174
# 126          CELTICS          HORNETS  0.027027
# 127          CELTICS   HOUSTONROCKETS  0.027027
# 125          CELTICS     CHICAGOBULLS  0.027027
# 253             CAVS          NUGGETS  0.026667
# 255             CAVS   DETROITPISTONS  0.026667
# 256             CAVS          CELTICS  0.026667
# 257             CAVS          RAPTORS  0.026667
# 254             CAVS     ORLANDOMAGIC  0.026667
# 151   DETROITPISTONS          NUGGETS  0.025000
# 146   DETROITPISTONS      WASHWIZARDS  0.025000
# 147   DETROITPISTONS           PACERS  0.025000
# 150   DETROITPISTONS         UTAHJAZZ  0.025000
# 149   DETROITPISTONS         MEMGRIZZ  0.025000
# 148   DETROITPISTONS   HOUSTONROCKETS  0.025000
# 291     CHICAGOBULLS      WASHWIZARDS  0.024390
# 292     CHICAGOBULLS           SIXERS  0.024390
# 289     CHICAGOBULLS          HORNETS  0.024390
# 288     CHICAGOBULLS       LACLIPPERS  0.024390
# 287     CHICAGOBULLS            SPURS  0.024390
# 286     CHICAGOBULLS          RAPTORS  0.024390
# 285     CHICAGOBULLS           PACERS  0.024390
# 293     CHICAGOBULLS     TIMBERWOLVES  0.024390
# 290     CHICAGOBULLS       DALLASMAVS  0.024390
# 374     BROOKLYNNETS          NUGGETS  0.023256
# 373     BROOKLYNNETS      PELICANSNBA  0.023256
# 372     BROOKLYNNETS     CHICAGOBULLS  0.023256
# 239         UTAHJAZZ         WARRIORS  0.023121
# 18        DALLASMAVS        MIAMIHEAT  0.022989
# 17        DALLASMAVS         NYKNICKS  0.022989
# 16        DALLASMAVS            SPURS  0.022989
# 71           NUGGETS      WASHWIZARDS  0.022901
# 70           NUGGETS            SPURS  0.022901
# 101            BUCKS             CAVS  0.022472
# 192         ATLHAWKS          CELTICS  0.021739
# 191         ATLHAWKS     BROOKLYNNETS  0.021739
# 193         ATLHAWKS            SPURS  0.019324
# 201         WARRIORS      WASHWIZARDS  0.019108
# 346          RAPTORS     TIMBERWOLVES  0.018182
# 347          RAPTORS      WASHWIZARDS  0.018182
# 307            SPURS         WARRIORS  0.017544
# 48              SUNS      WASHWIZARDS  0.017167
# 102            BUCKS         MEMGRIZZ  0.016854
# 234         MEMGRIZZ        MIAMIHEAT  0.016304
# 82            SIXERS         UTAHJAZZ  0.015544
# 321   HOUSTONROCKETS      PELICANSNBA  0.015385
# 320   HOUSTONROCKETS         NYKNICKS  0.015385
# 319   HOUSTONROCKETS            SPURS  0.015385
# 72           NUGGETS         NYKNICKS  0.015267
# 73           NUGGETS      PELICANSNBA  0.015267
# 74           NUGGETS          RAPTORS  0.015267
# 75           NUGGETS           PACERS  0.015267
# 276     ORLANDOMAGIC           PACERS  0.015038
# 194         ATLHAWKS   HOUSTONROCKETS  0.014493
# 35           HORNETS      PELICANSNBA  0.013889
# 36           HORNETS          RAPTORS  0.013889
# 37           HORNETS         WARRIORS  0.013889
# 38           HORNETS           LAKERS  0.013889
# 259             CAVS   HOUSTONROCKETS  0.013333
# 260             CAVS           PACERS  0.013333
# 258             CAVS     CHICAGOBULLS  0.013333
# 152   DETROITPISTONS       OKCTHUNDER  0.012500
# 153   DETROITPISTONS        MIAMIHEAT  0.012500
# 154   DETROITPISTONS         NYKNICKS  0.012500
# 195         ATLHAWKS           PACERS  0.012077
# 383     BROOKLYNNETS          HORNETS  0.011628
# 375     BROOKLYNNETS         UTAHJAZZ  0.011628
# 376     BROOKLYNNETS       OKCTHUNDER  0.011628
# 377     BROOKLYNNETS            SPURS  0.011628
# 381     BROOKLYNNETS            BUCKS  0.011628
# 379     BROOKLYNNETS         WARRIORS  0.011628
# 382     BROOKLYNNETS           SIXERS  0.011628
# 380     BROOKLYNNETS       DALLASMAVS  0.011628
# 378     BROOKLYNNETS        MIAMIHEAT  0.011628
# 103            BUCKS          CELTICS  0.011236
# 104            BUCKS          RAPTORS  0.011236
# 235         MEMGRIZZ       OKCTHUNDER  0.010870
# 215       LACLIPPERS     ORLANDOMAGIC  0.010870
# 83            SIXERS            SPURS  0.010363
# 196         ATLHAWKS     CHICAGOBULLS  0.009662
# 361      PELICANSNBA          RAPTORS  0.009434
# 360      PELICANSNBA      WASHWIZARDS  0.009434
# 348          RAPTORS            SPURS  0.009091
# 277     ORLANDOMAGIC            SPURS  0.007519
# 197         ATLHAWKS         NYKNICKS  0.007246
# 198         ATLHAWKS       OKCTHUNDER  0.007246
# 105            BUCKS           LAKERS  0.005618
# 107            BUCKS     CHICAGOBULLS  0.005618
# 106            BUCKS         NYKNICKS  0.005618
# 236         MEMGRIZZ           PACERS  0.005435
# 237         MEMGRIZZ         NYKNICKS  0.005435
# 216       LACLIPPERS       OKCTHUNDER  0.005435
# 200         ATLHAWKS        MIAMIHEAT  0.002415
# 199         ATLHAWKS           LAKERS  0.002415
# 403        MIAMIHEAT          NUGGETS  0.000000
# 404        MIAMIHEAT       OKCTHUNDER  0.000000
# 433           LAKERS         MEMGRIZZ  0.000000
# 405        MIAMIHEAT         NYKNICKS  0.000000
# 415           PACERS            SPURS  0.000000
# 389     BROOKLYNNETS             CAVS  0.000000
# 432           LAKERS        MIAMIHEAT  0.000000
# 422           LAKERS         UTAHJAZZ  0.000000
# 423           LAKERS     ORLANDOMAGIC  0.000000
# 424           LAKERS         NYKNICKS  0.000000
# 425           LAKERS          NUGGETS  0.000000
# 426           LAKERS          RAPTORS  0.000000
# 427           LAKERS            SPURS  0.000000
# 402        MIAMIHEAT           PACERS  0.000000
# 384     BROOKLYNNETS   DETROITPISTONS  0.000000
# 385     BROOKLYNNETS          CELTICS  0.000000
# 414           PACERS           SIXERS  0.000000
# 428           LAKERS       OKCTHUNDER  0.000000
# 429           LAKERS             SUNS  0.000000
# 401        MIAMIHEAT         WARRIORS  0.000000
# 386     BROOKLYNNETS           PACERS  0.000000
# 400        MIAMIHEAT         UTAHJAZZ  0.000000
# 416           PACERS             SUNS  0.000000
# 388     BROOKLYNNETS           LAKERS  0.000000
# 430           LAKERS      PELICANSNBA  0.000000
# 431           LAKERS           SIXERS  0.000000
# 387     BROOKLYNNETS         NYKNICKS  0.000000
# 217       LACLIPPERS         NYKNICKS  0.000000
# 327   HOUSTONROCKETS           LAKERS  0.000000
# 57        OKCTHUNDER           PACERS  0.000000
# 132          CELTICS         NYKNICKS  0.000000
# 131          CELTICS          RAPTORS  0.000000
# 130          CELTICS           PACERS  0.000000
# 129          CELTICS        MIAMIHEAT  0.000000
# 128          CELTICS           LAKERS  0.000000
# 110            BUCKS           PACERS  0.000000
# 109            BUCKS       OKCTHUNDER  0.000000
# 108            BUCKS        MIAMIHEAT  0.000000
# 76           NUGGETS       OKCTHUNDER  0.000000
# 61        OKCTHUNDER         WARRIORS  0.000000
# 60        OKCTHUNDER      PELICANSNBA  0.000000
# 59        OKCTHUNDER            SPURS  0.000000
# 58        OKCTHUNDER          RAPTORS  0.000000
# 56        OKCTHUNDER     ORLANDOMAGIC  0.000000
# 134          CELTICS      PELICANSNBA  0.000000
# 55        OKCTHUNDER     TIMBERWOLVES  0.000000
# 54        OKCTHUNDER           SIXERS  0.000000
# 53        OKCTHUNDER      WASHWIZARDS  0.000000
# 52        OKCTHUNDER             SUNS  0.000000
# 43           HORNETS        MIAMIHEAT  0.000000
# 42           HORNETS           PACERS  0.000000
# 41           HORNETS         NYKNICKS  0.000000
# 40           HORNETS   HOUSTONROCKETS  0.000000
# 39           HORNETS       OKCTHUNDER  0.000000
# 22        DALLASMAVS           PACERS  0.000000
# 21        DALLASMAVS      PELICANSNBA  0.000000
# 20        DALLASMAVS       OKCTHUNDER  0.000000
# 19        DALLASMAVS           LAKERS  0.000000
# 133          CELTICS       OKCTHUNDER  0.000000
# 135          CELTICS             SUNS  0.000000
# 326   HOUSTONROCKETS        MIAMIHEAT  0.000000
# 264             CAVS         NYKNICKS  0.000000
# 325   HOUSTONROCKETS          NUGGETS  0.000000
# 324   HOUSTONROCKETS       OKCTHUNDER  0.000000
# 323   HOUSTONROCKETS          RAPTORS  0.000000
# 322   HOUSTONROCKETS           PACERS  0.000000
# 301     CHICAGOBULLS           LAKERS  0.000000
# 300     CHICAGOBULLS        MIAMIHEAT  0.000000
# 299     CHICAGOBULLS         WARRIORS  0.000000
# 298     CHICAGOBULLS         NYKNICKS  0.000000
# 297     CHICAGOBULLS   HOUSTONROCKETS  0.000000
# 296     CHICAGOBULLS       OKCTHUNDER  0.000000
# 295     CHICAGOBULLS   DETROITPISTONS  0.000000
# 294     CHICAGOBULLS      PELICANSNBA  0.000000
# 265             CAVS       OKCTHUNDER  0.000000
# 263             CAVS             SUNS  0.000000
# 155   DETROITPISTONS      PELICANSNBA  0.000000
# 262             CAVS        MIAMIHEAT  0.000000
# 261             CAVS           LAKERS  0.000000
# 220       LACLIPPERS           LAKERS  0.000000
# 219       LACLIPPERS        MIAMIHEAT  0.000000
# 218       LACLIPPERS           PACERS  0.000000
# 171         NYKNICKS      PELICANSNBA  0.000000
# 170         NYKNICKS       OKCTHUNDER  0.000000
# 169         NYKNICKS            SPURS  0.000000
# 168         NYKNICKS          RAPTORS  0.000000
# 167         NYKNICKS           PACERS  0.000000
# 166         NYKNICKS     ORLANDOMAGIC  0.000000
# 157   DETROITPISTONS     ORLANDOMAGIC  0.000000
# 156   DETROITPISTONS           LAKERS  0.000000
# 434           LAKERS         WARRIORS  0.000000

# %%
# How has the number of conversations changed over time?

years = []
for index, row in df.iterrows():
    year = row['dates'][0][-4:]
    years.append(year)

output = set()
for x in years:
    output.add(x)
output = sorted(list(output))
f_years = []
counts = []

for x in output:
    f_years.append(x)
    counts.append(years.count(x))
    
year_count = pd.DataFrame(
        {'year': f_years,
         'count': counts
        }) 
        
print(year_count)
# Out:
#    year  count
# 0  2012      8
# 1  2013     42
# 2  2014    311
# 3  2015    523
# 4  2016    426
# 5  2017    461
# 6  2018    147

# %%
# What was the language of the tweets like/ \sentiment analysis

tweets = df['tweets']
names = df['usernames']
text = []
team = []

for tweet, name in zip(tweets,names):

    for c in tweet:
        text.append(c)
        
    for n in name:
        team.append(n)

neg = []
pos = []
neu = []
comp = []

analyzer = SentimentIntensityAnalyzer()

for t in text:
   vs = analyzer.polarity_scores(t)
   neg.append(vs['neg'])
   pos.append(vs['pos'])
   neu.append(vs['neu'])
   comp.append(vs['compound'])

all_tweets = pd.DataFrame(
        {'text': text,
         'team': team,
         'neg' : neg,
         'pos' : pos,
         'neu' : neu,
         'comp' : comp
        }) 

all_tweets=all_tweets[all_tweets['team'].isin(NBACAPS)]

print("Pos Avg: " + str(all_tweets['pos'].mean()))
print("Pos Max: " + str(all_tweets['pos'].max()))

print("Neg Avg: " + str(all_tweets['neg'].mean()))
print("Neg Max: " + str(all_tweets['neg'].max()))

print("Neu Avg: " + str(all_tweets['neu'].mean()))

print("Comp Avg: " + str(all_tweets['comp'].mean()))

negative = all_tweets[all_tweets['neg'] == 1]

print("\nMost Negative Tweets")
print(negative)

positive = all_tweets[all_tweets['pos'] == 1]
print("\nMost Positive Tweets")
print(positive)

pos_groups = all_tweets.groupby('team')['pos'].mean()
pos_groups = pos_groups.sort_values(ascending=False)
print("\nTeam Pos Avg")
print(pos_groups)

neg_groups = all_tweets.groupby('team')['neg'].mean()
neg_groups = neg_groups.sort_values(ascending=False)
print("\nTeam Neg Avg")
print(neg_groups)

comp_groups = all_tweets.groupby('team')['comp'].mean()
comp_groups = comp_groups.sort_values(ascending=False)
print("\nTeam Comp Avg")
print(comp_groups)
# Out:
# Pos Avg: 0.12222736801982086
# Pos Max: 1.0
# Neg Avg: 0.03069220506956356
# Neg Max: 1.0
# Neu Avg: 0.8356477987421385
# Comp Avg: 0.13271103487707261
#
# Most Negative Tweets
#              text             team  neg  pos  neu    comp
# 891      V CRAZY.         MEMGRIZZ  1.0  0.0  0.0 -0.3400
# 1184  V STRESSFUL         MEMGRIZZ  1.0  0.0  0.0 -0.5106
# 1811           NO  SACRAMENTOKINGS  1.0  0.0  0.0 -0.2960
# 1863        SORRY         ATLHAWKS  1.0  0.0  0.0 -0.0772
# 1962       SORRY?         ATLHAWKS  1.0  0.0  0.0 -0.0772
# 2180          UGH     TRAILBLAZERS  1.0  0.0  0.0 -0.4215
# 2801          UGH         MEMGRIZZ  1.0  0.0  0.0 -0.4215
# 3411         STOP     TIMBERWOLVES  1.0  0.0  0.0 -0.2960
# 4081           :/  SACRAMENTOKINGS  1.0  0.0  0.0 -0.3400
# 4103        SORRY  SACRAMENTOKINGS  1.0  0.0  0.0 -0.0772
# 5253  DOMINATING!         ATLHAWKS  1.0  0.0  0.0 -0.3595
#
# Most Positive Tweets
#                    text             team  neg  pos  neu    comp
# 1054                 OK      WASHWIZARDS  0.0  1.0  0.0  0.2960
# 1317          CREATIVE.           SIXERS  0.0  1.0  0.0  0.4404
# 1481              SUPER     TRAILBLAZERS  0.0  1.0  0.0  0.5994
# 1708          YES THX U     TRAILBLAZERS  0.0  1.0  0.0  0.6369
# 1772                 GG         ATLHAWKS  0.0  1.0  0.0  0.2960
# 2061       WELL PLAYED.     TRAILBLAZERS  0.0  1.0  0.0  0.5423
# 3181                 OK  SACRAMENTOKINGS  0.0  1.0  0.0  0.2960
# 3827           RESPECT.     TRAILBLAZERS  0.0  1.0  0.0  0.4767
# 3879              NEAT.     TRAILBLAZERS  0.0  1.0  0.0  0.4588
# 3951               COOL     TRAILBLAZERS  0.0  1.0  0.0  0.3182
# 4045  NICE WIN, FRIENDS  SACRAMENTOKINGS  0.0  1.0  0.0  0.8658
# 4379                LOL         UTAHJAZZ  0.0  1.0  0.0  0.4215
# 4839           RESPECT.             SUNS  0.0  1.0  0.0  0.4767
# 4913            AMAZING         MEMGRIZZ  0.0  1.0  0.0  0.5859
#
# Team Pos Avg
# team
# ATLHAWKS           0.160277
# MEMGRIZZ           0.156199
# MIAMIHEAT          0.149794
# ORLANDOMAGIC       0.148140
# TRAILBLAZERS       0.147007
# DETROITPISTONS     0.137706
# BROOKLYNNETS       0.134970
# WARRIORS           0.131803
# DALLASMAVS         0.130246
# PACERS             0.129538
# WASHWIZARDS        0.127549
# LACLIPPERS         0.121614
# RAPTORS            0.120675
# HORNETS            0.118018
# UTAHJAZZ           0.115540
# SACRAMENTOKINGS    0.113023
# NUGGETS            0.109129
# BUCKS              0.108150
# PELICANSNBA        0.108118
# NYKNICKS           0.105895
# TIMBERWOLVES       0.104680
# SIXERS             0.092176
# SUNS               0.091823
# CAVS               0.088948
# HOUSTONROCKETS     0.083922
# CELTICS            0.075659
# CHICAGOBULLS       0.069694
# SPURS              0.057094
# OKCTHUNDER         0.038706
# LAKERS             0.018250
# Name: pos, dtype: float64
#
# Team Neg Avg
# team
# MEMGRIZZ           0.065299
# CELTICS            0.055545
# SACRAMENTOKINGS    0.052413
# RAPTORS            0.037669
# TIMBERWOLVES       0.034363
# SIXERS             0.034135
# LACLIPPERS         0.031522
# TRAILBLAZERS       0.031263
# UTAHJAZZ           0.030728
# ATLHAWKS           0.030288
# DETROITPISTONS     0.029735
# SUNS               0.028809
# PELICANSNBA        0.027787
# SPURS              0.027688
# MIAMIHEAT          0.027471
# PACERS             0.027154
# HORNETS            0.026200
# CAVS               0.024474
# NUGGETS            0.022955
# DALLASMAVS         0.021016
# HOUSTONROCKETS     0.020325
# BUCKS              0.017937
# BROOKLYNNETS       0.017616
# ORLANDOMAGIC       0.017462
# WASHWIZARDS        0.015698
# WARRIORS           0.014175
# CHICAGOBULLS       0.007980
# NYKNICKS           0.006737
# LAKERS             0.000000
# OKCTHUNDER         0.000000
# Name: neg, dtype: float64
#
# Team Comp Avg
# team
# ATLHAWKS           0.205138
# ORLANDOMAGIC       0.179652
# WASHWIZARDS        0.179648
# PACERS             0.171633
# WARRIORS           0.170801
# DALLASMAVS         0.170058
# DETROITPISTONS     0.167894
# MIAMIHEAT          0.163768
# BROOKLYNNETS       0.160759
# NYKNICKS           0.147195
# CHICAGOBULLS       0.146641
# TRAILBLAZERS       0.134469
# HORNETS            0.133519
# RAPTORS            0.132392
# SUNS               0.127367
# UTAHJAZZ           0.127129
# BUCKS              0.112486
# PELICANSNBA        0.112476
# LACLIPPERS         0.110132
# TIMBERWOLVES       0.107235
# SACRAMENTOKINGS    0.105142
# HOUSTONROCKETS     0.103729
# MEMGRIZZ           0.101925
# NUGGETS            0.093402
# CAVS               0.087159
# CELTICS            0.085234
# OKCTHUNDER         0.079712
# SIXERS             0.068205
# SPURS              0.064430
# LAKERS             0.035125
# Name: comp, dtype: float64
