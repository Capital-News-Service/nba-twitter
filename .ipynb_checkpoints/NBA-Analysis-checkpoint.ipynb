# %% [markdown]
# Jake Gluck - Capital News Service - jagluck.github.io
#
# NBA Twitter Analysis

# %%
#import libraries
import pandas as pd
import numpy as np
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
#load twitter conv data gathered by the scraper
df = pd.read_csv('/Users/jagluck/Documents/GitHub/nba-twitter/nba-conv.csv')

NBACAPS = {'CAVS','OKCTHUNDER','CELTICS','NYKNICKS','BROOKLYNNETS','PELICANSNBA', 'PACERS', 'ORLANDOMAGIC','TIMBERWOLVES','MIAMIHEAT',
'HORNETS', 'DETROITPISTONS', 'DALLASMAVS', 'LACLIPPERS', 'LAKERS', 'UTAHJAZZ', 'NUGGETS', 'WASHWIZARDS', 'CHICAGOBULLS',
'SPURS', 'SUNS', 'HOUSTONROCKETS', 'WARRIORS', 'ATLHAWKS', 'MEMGRIZZ', 'BUCKS', 'RAPTORS', 'SACRAMENTOKINGS', 'SIXERS', 'TRAILBLAZERS'}

#coverts to list of strings
def convertType(toConv, makeUpper):

    toConv = toConv.str.replace("'", "")
    toConv = toConv.str.replace("@", " ")
    
    if makeUpper:
        toConv = toConv.str.upper()
          
    toConv = toConv.str.strip("[]")
    toConv = toConv.str.split(',')
    
    count1 = 0
    for x in toConv:
        count2 = 0
        for y in x:
            toConv[count1][count2] = y.strip()
            count2 = count2 + 1
        count1 = count1 + 1
        
    return toConv

def convertTypeTweet(toConv):

    toConv = toConv.str.replace("'", "")
    toConv = toConv.str.replace("@", " ")
    
    if makeUpper:
        toConv = toConv.str.upper()
          
    toConv = toConv.str.strip("[]")
    toConv = toConv.str.split(',')
    
    count1 = 0
    for x in toConv:
        count2 = 0
        for y in x:
            toConv[count1][count2] = y.strip()
            count2 = count2 + 1
        count1 = count1 + 1
        
    return toConv

# Helper: counts time value is in list of lists
def countContains(toCount, data):
    count = 0
    for x in data:
        if toCount in x:
            count = count + 1
    return count

# Helper: stores value when value in list of list is found
def countLengths(toCount, data1, data2):
    count = []
    for x, y in zip(data1, data2):
        if toCount in x:
            count.append(y)
    return np.mean(count)
    
# convert types  
df = df.drop(['Unnamed: 0'], axis=1)
df = df.drop(['to'], axis=1)
df = df.drop(['from'], axis=1)
df['names'] = convertType(df['names'], False)
df['usernames'] = convertType(df['usernames'], True)
df['dates'] = convertType(df['dates'], True)
print(df['tweets'])
df['tweets'] = convertTypeTweet(df['tweets'])
# Out:
# 0       ['Waiting on @NBA season like... \n\n#IsItOcto...
# 1       ['Waiting for the season to begin like... #NBA...
# 2       ['@ATLHawks @Suns @denvernuggets @Sixers @warr...
# 3       ['@DetroitPistons @MNTimberwolves @Suns @denve...
# 4       [".@Sixers @warriors We're just going around t...
# 5       ['According to our mentions, we should trade f...
# 6       ['We’re picking up what you’re putting down… #...
# 7       ["@hornets Let's talk Big Al. He looks like he...
# 8       ['And the @hornets are staying true to form, n...
# 9       ['@Suns @dallasmavs @denvernuggets @Bucks @Six...
# 10      ["Who's up for a real one, #NBASitcoms? @Detro...
# 11      ['.@denvernuggets @ATLHawks @Sixers @warriors ...
# 12      ['@Suns @Sixers @warriors @trailblazerspic.twi...
# 13      ['@Suns @Sixers @warriors @trailblazers Kale K...
# 14      ["Shout out @Sixers @trailblazers @suns & @ATL...
# 15      ['@ATLHawks @Suns @Sixers @warriors @trailblaz...
# 16      ["@MNTimberwolves @ATLHawks @Suns @denvernugge...
# 17      ["@ATLHawks we'll be patiently twiddling our t...
# 18      ["@WashWizards What's up friends! How's your T...
# 19      ["We'll trade you today's tweet for tomorrow's...
# 20      ['.@warriors Saaaame. #NBAOffseasonpic.twitter...
# 21      ["@utahjazz Can't see why not, it's fun to wat...
# 22      [".@dallasmavs Did you say #GIFParty? We'll se...
# 23      ['@utahjazz Us too! Great to see Coach Snyder ...
# 24      ["@utahjazz What's up friends! Thanks for taki...
# 25      ["@WashWizards Wall just keeps getting better ...
# 26      [".@Sixers @ATLHawks @warriors @trailblazers I...
# 27      ["@WashWizards Us too. Looking forward to seei...
# 28      ['It’s not a #GIFparty unless @zaza27 is there...
# 29      ['. @Sixers @denvernuggets guys...we like #NBA...
#                               ...
# 2952    ['.@LAClipperspic.twitter.com/JSAHshQ3cK', '¯\...
# 2953    [".@ATLHawks can we switch to #NBAGameshows? L...
# 2954    [" @ATLHawks, we're here \n#WizHawkspic.twitte...
# 2955    ['Same.https://twitter.com/cmillscsn/status/79...
# 2956    ['If you like alley-oops to @Keefmorris, check...
# 2957    ['The @ATLHawks are here tonight, so we just h...
# 2958    ['Tight 1st Q here.\n\nGasol: 14pts/3rb\nButle...
# 2959    ['10 minutes until the #NBASchedule drops! \n\...
# 2960    ['Hollywood loves a sequel https://vine.co/v/i...
# 2961    ['What a Q1 for @JohnWall!  13p-6a, #Wizards u...
# 2962    ["Nice list RT @ATLHawks: ICYMI, here's where ...
# 2963    ["Game update: still killin' it.\n\n#Nuggetspi...
# 2964    ["This arrived today. Wonder what's inside?pic...
# 2965    ['Sup, @ATLHawks.pic.twitter.com/F5pcsE2Ejk', ...
# 2966    ['What song do you want to hear during the 4th...
# 2967    ["You're right... but those wins are pretty ex...
# 2968    ['Hey, @LAClippers! \n\nYou ready?pic.twitter....
# 2969    ['.@AlexLen-mon Heads #NBASweets', "@Suns You'...
# 2970                               ['Current mood: ', '']
# 2971    ['*Checks schedule page*\n*Refresh*\n*Repeat*'...
# 2972    ["With tonight's news that @UFC is coming to P...
# 2973    ['4 point play!  #Nets lead 100-98 with 15.3 t...
# 2974                   ['JARR3TT JACK', '@BrooklynNets ']
# 2975    ['.@ATLHawks how have you not gone Adreian Hou...
# 2976    ['Back to #IgniteTheFuture #NBAMoviespic.twitt...
# 2977    ['.@ATLHawks At least the weather has been nic...
# 2978    ['Jazz // @LAClippers - Sunday Showdown \n\nGa...
# 2979    ['Hey @ATLHawks when we do this at your place ...
# 2980    ['Oh wow #NBAFinals', '@dallasmavs walking the...
# 2981    ['REG-GIE. REG-GIE.\n\nTwo more at the line an...
# Name: tweets, Length: 2982, dtype: object
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-70a42273c7ea> in <module>()
#      73 df['dates'] = convertType(df['dates'], True)
#      74 print(df['tweets'])
# ---> 75 df['tweets'] = convertTypeTweet(df['tweets'])
#
# <ipython-input-24-70a42273c7ea> in convertTypeTweet(toConv)
#      33     toConv = toConv.str.replace("@", " ")
#      34
# ---> 35     if makeUpper:
#      36         toConv = toConv.str.upper()
#      37
#
# NameError: name 'makeUpper' is not defined

# %%
## What is the typical converation size? ##########
df['size'].describe()
# Out:
# count    2982.000000
# mean        3.199531
# std         2.175947
# min         2.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max        11.000000
# Name: size, dtype: float64

# %%
### What teams Tweet the most #######
names = []
participations = []
lengths = []
for name in NBACAPS:
    names.append(name)
    participations.append(countContains(name,df['usernames']))
    lengths.append(countLengths(name,df['usernames'],df['size']))

teams = pd.DataFrame(
        {'name': names,
         'participation': participations,
         'avg_lengths': lengths
        })
    
teams = teams.sort_values(by='participation', ascending=False)
print(teams)

#What teams have the longest and shortest conversations
teams = teams.sort_values(by='avg_lengths', ascending=False)
print(teams)

#What teams talk to other teams the most/least? 

def countDuoConvos(name, name2):
    count = 0
    for x in df['usernames']:
        if name in x:
            if name2 in x:
                count = count + 1
    return count
 
tos = []
froms = []
convo_counts = []

for name in NBACAPS:
    for name2 in NBACAPS:
        if name != name2:
            tos.append(name)
            froms.append(name2)
            convo_counts.append(countDuoConvos(name, name2))
                
convos = pd.DataFrame(
        {'team_1': tos,
         'team_2': froms,
         'convo_count': convo_counts
        })
 
convos = convos.sort_values(by='convo_count', ascending=False)       
print(convos)
# Out:
#     avg_lengths             name  participation
# 26     2.815327     TRAILBLAZERS            796
# 5      4.104435         ATLHAWKS            699
# 20     2.992874  SACRAMENTOKINGS            421
# 4      3.480000         WARRIORS            400
# 22     3.423858     TIMBERWOLVES            394
# 19     4.471850             SUNS            373
# 14     3.219653       LACLIPPERS            346
# 29     3.812883           SIXERS            326
# 25     3.379421         UTAHJAZZ            311
# 2      3.063433         MEMGRIZZ            268
# 11     3.926641            BUCKS            259
# 17     6.059406       DALLASMAVS            202
# 7      6.244048          HORNETS            168
# 9      4.283951          NUGGETS            162
# 27     3.655629      WASHWIZARDS            151
# 23     3.202797     ORLANDOMAGIC            143
# 6      2.925373          RAPTORS            134
# 1      2.632479      PELICANSNBA            117
# 8      4.513514   DETROITPISTONS            111
# 28     2.550459     BROOKLYNNETS            109
# 18     3.009901             CAVS            101
# 16     3.573034            SPURS             89
# 0      2.910256   HOUSTONROCKETS             78
# 3      3.910714     CHICAGOBULLS             56
# 12     2.450000           PACERS             40
# 10     2.736842        MIAMIHEAT             38
# 15     4.368421          CELTICS             38
# 21     3.846154         NYKNICKS             26
# 13     2.800000       OKCTHUNDER             25
# 24     2.000000           LAKERS             20
#     avg_lengths             name  participation
# 7      6.244048          HORNETS            168
# 17     6.059406       DALLASMAVS            202
# 8      4.513514   DETROITPISTONS            111
# 19     4.471850             SUNS            373
# 15     4.368421          CELTICS             38
# 9      4.283951          NUGGETS            162
# 5      4.104435         ATLHAWKS            699
# 11     3.926641            BUCKS            259
# 3      3.910714     CHICAGOBULLS             56
# 21     3.846154         NYKNICKS             26
# 29     3.812883           SIXERS            326
# 27     3.655629      WASHWIZARDS            151
# 16     3.573034            SPURS             89
# 4      3.480000         WARRIORS            400
# 22     3.423858     TIMBERWOLVES            394
# 25     3.379421         UTAHJAZZ            311
# 14     3.219653       LACLIPPERS            346
# 23     3.202797     ORLANDOMAGIC            143
# 2      3.063433         MEMGRIZZ            268
# 18     3.009901             CAVS            101
# 20     2.992874  SACRAMENTOKINGS            421
# 6      2.925373          RAPTORS            134
# 0      2.910256   HOUSTONROCKETS             78
# 26     2.815327     TRAILBLAZERS            796
# 13     2.800000       OKCTHUNDER             25
# 10     2.736842        MIAMIHEAT             38
# 1      2.632479      PELICANSNBA            117
# 28     2.550459     BROOKLYNNETS            109
# 12     2.450000           PACERS             40
# 24     2.000000           LAKERS             20
#      convo_count           team_1           team_2
# 758          110     TRAILBLAZERS         WARRIORS
# 141          110         WARRIORS     TRAILBLAZERS
# 208           88          HORNETS         ATLHAWKS
# 151           88         ATLHAWKS          HORNETS
# 498           86       DALLASMAVS         ATLHAWKS
# 161           86         ATLHAWKS       DALLASMAVS
# 163           85         ATLHAWKS             SUNS
# 556           85             SUNS         ATLHAWKS
# 768           76     TRAILBLAZERS       LACLIPPERS
# 431           76       LACLIPPERS     TRAILBLAZERS
# 166           75         ATLHAWKS     TIMBERWOLVES
# 643           75     TIMBERWOLVES         ATLHAWKS
# 750           73         UTAHJAZZ     TRAILBLAZERS
# 779           73     TRAILBLAZERS         UTAHJAZZ
# 657           64     TIMBERWOLVES             SUNS
# 572           64             SUNS     TIMBERWOLVES
# 579           63             SUNS           SIXERS
# 860           63           SIXERS             SUNS
# 774           60     TRAILBLAZERS  SACRAMENTOKINGS
# 605           60  SACRAMENTOKINGS     TRAILBLAZERS
# 219           59          HORNETS       DALLASMAVS
# 500           59       DALLASMAVS          HORNETS
# 773           57     TRAILBLAZERS             SUNS
# 576           57             SUNS     TRAILBLAZERS
# 120           54         WARRIORS         ATLHAWKS
# 170           54         ATLHAWKS     TRAILBLAZERS
# 149           54         ATLHAWKS         WARRIORS
# 759           54     TRAILBLAZERS         ATLHAWKS
# 134           53         WARRIORS             SUNS
# 555           53             SUNS         WARRIORS
# ..           ...              ...              ...
# 358            0           PACERS        MIAMIHEAT
# 355            0           PACERS          HORNETS
# 348            0           PACERS   HOUSTONROCKETS
# 386            0       OKCTHUNDER          NUGGETS
# 388            0       OKCTHUNDER            BUCKS
# 702            0           LAKERS          RAPTORS
# 713            0           LAKERS       DALLASMAVS
# 401            0       OKCTHUNDER         UTAHJAZZ
# 704            0           LAKERS   DETROITPISTONS
# 705            0           LAKERS          NUGGETS
# 706            0           LAKERS        MIAMIHEAT
# 400            0       OKCTHUNDER           LAKERS
# 399            0       OKCTHUNDER     ORLANDOMAGIC
# 709            0           LAKERS       OKCTHUNDER
# 710            0           LAKERS       LACLIPPERS
# 711            0           LAKERS          CELTICS
# 712            0           LAKERS            SPURS
# 714            0           LAKERS             CAVS
# 389            0       OKCTHUNDER           PACERS
# 715            0           LAKERS             SUNS
# 717            0           LAKERS         NYKNICKS
# 397            0       OKCTHUNDER         NYKNICKS
# 719            0           LAKERS     ORLANDOMAGIC
# 720            0           LAKERS         UTAHJAZZ
# 395            0       OKCTHUNDER             SUNS
# 723            0           LAKERS     BROOKLYNNETS
# 394            0       OKCTHUNDER             CAVS
# 392            0       OKCTHUNDER            SPURS
# 391            0       OKCTHUNDER          CELTICS
# 362            0           PACERS          CELTICS
#
# [870 rows x 3 columns]

# %%
# What percent of each team is sent to other teams

team_name = []
to_name = []
percent = []
for t_index, t_row in teams.iterrows():
    total = t_row['participation']
    name = t_row['name']
    for c_index, c_row in convos.iterrows():
        if (name == c_row['team_1']):
            team_name.append(name)
            to_name.append(c_row['team_2'])
            count = c_row['convo_count']
            if (count == 0):
                percent.append(0)
            else:
                percent.append(c_row['convo_count']/total)
            
convo_percent = pd.DataFrame(
        {'from': team_name,
         'to': to_name,
         'percent': percent
        })
        
convo_percent = convo_percent.sort_values(by='percent', ascending=False)  
print(convo_percent)
# Out:
#                from   percent               to
# 0           HORNETS  0.523810         ATLHAWKS
# 696      OKCTHUNDER  0.480000     TRAILBLAZERS
# 29       DALLASMAVS  0.425743         ATLHAWKS
# 1           HORNETS  0.351190       DALLASMAVS
# 551            CAVS  0.297030         ATLHAWKS
# 30       DALLASMAVS  0.292079          HORNETS
# 377        WARRIORS  0.275000     TRAILBLAZERS
# 319     WASHWIZARDS  0.271523         ATLHAWKS
# 58   DETROITPISTONS  0.270270         ATLHAWKS
# 261        NYKNICKS  0.269231           SIXERS
# 59   DETROITPISTONS  0.261261     TIMBERWOLVES
# 841          LAKERS  0.250000     TRAILBLAZERS
# 232    CHICAGOBULLS  0.250000  SACRAMENTOKINGS
# 117         CELTICS  0.236842     TRAILBLAZERS
# 116         CELTICS  0.236842         ATLHAWKS
# 435        UTAHJAZZ  0.234727     TRAILBLAZERS
# 638  HOUSTONROCKETS  0.230769     TRAILBLAZERS
# 87             SUNS  0.227882         ATLHAWKS
# 464      LACLIPPERS  0.219653     TRAILBLAZERS
# 493    ORLANDOMAGIC  0.216783         ATLHAWKS
# 60   DETROITPISTONS  0.216216             SUNS
# 783    BROOKLYNNETS  0.211009     TRAILBLAZERS
# 348           SPURS  0.202247  SACRAMENTOKINGS
# 842          LAKERS  0.200000     TIMBERWOLVES
# 812          PACERS  0.200000     TRAILBLAZERS
# 61   DETROITPISTONS  0.198198            BUCKS
# 290          SIXERS  0.193252             SUNS
# 31       DALLASMAVS  0.193069             SUNS
# 263        NYKNICKS  0.192308             SUNS
# 262        NYKNICKS  0.192308      WASHWIZARDS
# ..              ...       ...              ...
# 282        NYKNICKS  0.000000       LACLIPPERS
# 283        NYKNICKS  0.000000       OKCTHUNDER
# 284        NYKNICKS  0.000000        MIAMIHEAT
# 285        NYKNICKS  0.000000   DETROITPISTONS
# 521    ORLANDOMAGIC  0.000000           LAKERS
# 746       MIAMIHEAT  0.000000   HOUSTONROCKETS
# 745       MIAMIHEAT  0.000000       OKCTHUNDER
# 744       MIAMIHEAT  0.000000         WARRIORS
# 255    CHICAGOBULLS  0.000000        MIAMIHEAT
# 719      OKCTHUNDER  0.000000           PACERS
# 720      OKCTHUNDER  0.000000         NYKNICKS
# 721      OKCTHUNDER  0.000000             SUNS
# 722      OKCTHUNDER  0.000000             CAVS
# 723      OKCTHUNDER  0.000000            SPURS
# 724      OKCTHUNDER  0.000000          CELTICS
# 574            CAVS  0.000000        MIAMIHEAT
# 231           BUCKS  0.000000       OKCTHUNDER
# 254    CHICAGOBULLS  0.000000      PELICANSNBA
# 256    CHICAGOBULLS  0.000000   DETROITPISTONS
# 743       MIAMIHEAT  0.000000     CHICAGOBULLS
# 257    CHICAGOBULLS  0.000000           LAKERS
# 258    CHICAGOBULLS  0.000000         NYKNICKS
# 86   DETROITPISTONS  0.000000     CHICAGOBULLS
# 259    CHICAGOBULLS  0.000000   HOUSTONROCKETS
# 260    CHICAGOBULLS  0.000000       OKCTHUNDER
# 276        NYKNICKS  0.000000           LAKERS
# 740       MIAMIHEAT  0.000000          HORNETS
# 741       MIAMIHEAT  0.000000            BUCKS
# 742       MIAMIHEAT  0.000000          NUGGETS
# 869          LAKERS  0.000000     BROOKLYNNETS
#
# [870 rows x 3 columns]

# %%
# How has the number of conversations changed over time?

years = []
for index, row in df.iterrows():
    year = row['dates'][0][-4:]
    years.append(year)

output = set()
for x in years:
    output.add(x)
output = sorted(list(output))
f_years = []
counts = []

for x in output:
    f_years.append(x)
    counts.append(years.count(x))
    
year_count = pd.DataFrame(
        {'year': f_years,
         'count': counts
        }) 
        
print(year_count)
# Out:
#    count  year
# 0     10  2012
# 1     50  2013
# 2    545  2014
# 3    890  2015
# 4    665  2016
# 5    822  2017

# %%
# What was the language of the tweets like/ \sentiment analysis

tweets = df['tweets']
names = df['usernames']
text = []
team = []

for tweet in tweets:
    b = eval(tweet)
    for c in b:
        text.append(c)
for name in names:
    for n in name:
        team.append(n)

neg = []
pos = []
neu = []
comp = []

analyzer = SentimentIntensityAnalyzer()

for t in text:
   vs = analyzer.polarity_scores(t)
   neg.append(vs['neg'])
   pos.append(vs['pos'])
   neu.append(vs['neu'])
   comp.append(vs['compound'])

all_tweets = pd.DataFrame(
        {'text': text,
         'team': team,
         'neg' : neg,
         'pos' : pos,
         'neu' : neu,
         'comp' : comp
        }) 
      
all_tweets=all_tweets[all_tweets['team'].isin(NBACAPS)]

print("Pos Avg: " + str(all_tweets['pos'].mean()))
print("Pos Max: " + str(all_tweets['pos'].max()))

print("Neg Avg: " + str(all_tweets['neg'].mean()))
print("Neg Max: " + str(all_tweets['neg'].max()))

print("Neu Avg: " + str(all_tweets['neu'].mean()))

print("Comp Avg: " + str(all_tweets['comp'].mean()))

negative = all_tweets[all_tweets['neg'] == 1]
print("\nMost Negative Tweets")
print(negative)

positive = all_tweets[all_tweets['pos'] == 1]
print("\nMost Positive Tweets")
print(positive)

pos_groups = all_tweets.groupby('team')['pos'].mean()
pos_groups = groups.sort_values(ascending=False)
print("\nTeam Pos Avg")
print(pos_groups)

neg_groups = all_tweets.groupby('team')['neg'].mean()
neg_groups = groups.sort_values(ascending=False)
print("\nTeam Neg Avg")
print(neg_groups)

comp_groups = all_tweets.groupby('team')['comp'].mean()
comp_groups = groups.sort_values(ascending=False)
print("\nTeam Comp Avg")
print(comp_groups)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-58434bf38c60> in <module>()
#      26    pos.append(vs['pos'])
#      27    neu.append(vs['neu'])
# ---> 28    comp.append(vs['comp'])
#      29
#      30 all_tweets = pd.DataFrame(
#
# KeyError: 'comp'
